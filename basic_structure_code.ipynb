# %%
import openai
import os
import pptx

# Set up OpenAI API key
openai.api_key = "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"

# %%
import json
# new
from openai import OpenAI

client = OpenAI(
  api_key="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"
)


# Define the learning system class
class LearningSystem:
    def __init__(self, course_name, course_structure):
        self.course_name = course_name
        self.course_structure = course_structure

        self.available_weeks = list(course_structure.keys())

    def chat_with_gpt(self, prompt):
        """Interacts with ChatGPT API to get a response for a prompt."""
        try:
            response = client.chat.completions.create(
                                                        model="gpt-4o-mini",
                                                        messages=[
                                                            {
                                                                "role": "user",
                                                                "content": prompt,
                                                            },
                                                        ],
                                                    )
            return response.choices[0].message.content
        except Exception as e:
            print(f"Error: {e}")
            return "Sorry, I couldn't process your request."

    def start_course(self):
        print(f"Welcome to {self.course_name}! Let's start learning.")
        self.show_weeks()

    def show_weeks(self):
        print("\nAvailable Weeks:")
        weeks = list(self.course_structure.keys())
        for i, week in enumerate(weeks, 1):
            print(f"{i}. {week}")

        selected_week = input("\nEnter the week number you want to study (or type 'exit' to quit): ").strip()
        if selected_week.lower() == 'exit':
            self.selected_week = selected_week
            print("Goodbye! Happy Learning!")
            return

        if selected_week.isdigit() and 1 <= int(selected_week) <= len(weeks):
            self.selected_week = weeks[int(selected_week)-1]
            self.show_days(weeks[int(selected_week) - 1])
        else:
            print("Invalid selection. Please try again.")
            self.show_weeks()

    def show_days(self, week):
        print(f"\nDays in {week}:")
        days = list(self.course_structure[week].keys())
        for i, day in enumerate(days, 1):
            print(f"{i}. {day}")

        selected_day = input("\nEnter the day number to study (or type 'back' to select another week): ").strip()
        if selected_day.lower() == 'back':
            self.selected_day = selected_day
            self.show_weeks()
        elif selected_day.isdigit() and 1 <= int(selected_day) <= len(days):
            self.selected_day = days[int(selected_day)-1]
            self.show_topics(week, days[int(selected_day) - 1])
        else:
            print("Invalid selection. Please try again.")
            self.show_days(week)

    def show_topics(self, week, day):
        print(f"\nTopics/Activities for {day} in {week}:")
        content = self.course_structure[week][day]
        topics = []
    
        # Ensure all components are lists
        for key in ["Topics", "Exercises", "Activities", "Project Ideas"]:
            value = content.get(key, [])
            if isinstance(value, str):  # If the value is a string, convert to a list
                value = [value]
            topics += value
    
        for i, topic in enumerate(topics, 1):
            print(f"{i}. {topic}")
    
        selected_topic = input("\nEnter the topic number to start (or type 'back' to select another day): ").strip()
        if selected_topic.lower() == 'back':
            self.show_days(week)
        elif selected_topic.isdigit() and 1 <= int(selected_topic) <= len(topics):
            self.selected_topic = topics[int(selected_topic)-1]
            self.teach_topic(topics[int(selected_topic) - 1])
        else:
            print("Invalid selection. Please try again.")
            self.show_topics(week, day)


    def teach_topic(self, topic):
        
        prompt = f"By going through: {self.read_days_lecture()}. Explain the topic '{topic}' in simple terms suitable for a beginner."
        explanation = self.chat_with_gpt(prompt)
        print(f"\n{explanation}\n")

        self.quiz_topic(topic)

    def quiz_topic(self, topic):
        if input("\nDo you want to take a quiz y for Yes and n for no: ").strip() == "y":
            
            prompt = f"Create a short quiz with 3 questions on the topic '{topic}' with answers."
            quiz_content = self.chat_with_gpt(prompt)
            print(f"\nQuiz for topic '{topic}':")
            print(quiz_content)
    
            input("Press Enter to continue...")
            self.show_weeks()

    def read_days_lecture(self):
        try:
            with open(f"course/lecture_notes/{self.selected_week}/{self.selected_day}.txt", 'r', encoding="utf-8") as f:
                content = f.readlines()
                return "".join([line.strip() for line in content if line.strip()])
        except FileNotFoundError:
            print(f"Error: The file {file_path} does not exist.")
            return None
        

if __name__ == "__main__":
    # Read the syllabus from a JSON file
    with open("course/syllabus.json", "r") as file:
        syllabus_json = json.load(file)

    course_name = "Python for Beginners"
    course_structure = syllabus_json[course_name]

    system = LearningSystem(course_name, course_structure)
    system.start_course()
# Out:
# Welcome to Python for Beginners! Let's start learning.
#
# Available Weeks:
# 1. Week 1 Introduction to Python and Basic Concepts
# 2. Week 2 Data Structures and Functions
# 3. Week 3 Modules, File Handling, and Error Handling
# 4. Week 4 Advanced Topics and Final Project
# Enter the week number you want to study (or type 'exit' to quit):  2
# Days in Week 2 Data Structures and Functions:
# 1. day01
# 2. day02
# 3. day03
# 4. day04
# 5. day05
# Enter the day number to study (or type 'back' to select another week):  2
# Topics/Activities for day02 in Week 2 Data Structures and Functions:
# 1. Lists
# 2. Creating and Manipulating Lists
# 3. List Comprehension
# Enter the topic number to start (or type 'back' to select another day):  2
# Sure! Let’s break down the topic of "Creating and Manipulating Lists" in simple terms.
#
# ### What is a List?
# ...
